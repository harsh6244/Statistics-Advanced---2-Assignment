# %% [markdown]
# # **Statics Advance 2 Assignment**

# %% [markdown]
# **Q1- What is hypothesis testing in statistics?**
#
# Answer - It's a claim or statement or an assumption aboout a population parameter that can be tested using statical method.
#
# Examples
#
# Average salary of IIT employee is 50k
# Consumption of ice-cream is more in summer
#
# **Hypothesis Testing**
#
# *  You made a claim about population (say average age is 45 yrs)
# *  Due to time and resource constraints you can not go to each person of population to record age.
# *  Take sample calculate average age of sample & check if the sample average age is close to the claim that you have made about population.

# %% [markdown]
# **Q.2 What is the null hypothesis, and how does it differ from the alternative
# hypothesis?**
#
# Answer -
#
# **Null hypothesis** - The initial or null assumption.
#
# eg: Person is not guilty
#
# **Alternate hypothesis** - Opposite of null hypothesis
#
# eg: Person is guilty

# %% [markdown]
# **Q.3 Explain the significance level in hypothesis testing and its role in deciding
# the outcome of a test**
#
# Answer - The significance level, commonly denoted by (alpha), is a crucial concept in hypothesis testing. It helps you decide whether to reject or fail to reject the null hypothesis (H₀) based on the probability of observing your test results under the assumption that the null hypothesis is true.
#
# **Role in Hypothesis Testing**
#
# *   Set Before Testing:
# Before performing a test, the researcher selects a significance level (e.g., α = 0.05).
#
# *   Compare with p-value:
# After calculating the p-value (the probability of observing the data assuming H₀ is true), you:
#
#       Reject H₀ if: p-value ≤ α
#
#      Fail to reject H₀ if: p-value > α
#
# *   Determines Critical Region:
# The significance level helps define the critical region — the set of values where H₀ is rejected.

# %% [markdown]
# **Q.4 What are Type I and Type II errors? Give examples of each**
#
# Answer -
# *  Type - I error - Is the rejection of the null hypothesis when it is actually true.
#
#      eg; An innocent person is convicted.
#
# *  Type - II error - Is the failure to reject the null hypothesis.
#
#     eg; A guilty person may not be convicted.

# %% [markdown]
# **Q.5 What is the difference between a Z-test and a T-test? Explain when to use
# each.**
#
# Answer - Both Z-test and T-test are statistical methods used to compare sample data and draw conclusions about population parameters — often used in hypothesis testing. However, they differ mainly in the conditions of use and the type of data they are suited for.
#
#
# If population standard deviation is given and sample size greater than 30 then we use z test, otherwise T test.

# %% [markdown]
# Q.6 Write a Python program to generate a binomial distribution with n=10 and
# p=0.5, then plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the binomial distribution
n = 10        # Number of trials
p = 0.5       # Probability of success
size = 1000   # Number of samples

# Generate binomial distribution data
data = np.random.binomial(n=n, p=p, size=size)

# Plot histogram
plt.hist(data, bins=range(n + 2), edgecolor='black', align='left')
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# Question 7: Implement hypothesis testing using Z-statistics for a sample dataset in
# Python. Show the Python code and interpret the results.
# sample_data = [49.1, 50.2, 51.0, 48.7, 50.5, 49.8, 50.3, 50.7, 50.2, 49.6,
# 50.1, 49.9, 50.8, 50.4, 48.9, 50.6, 50.0, 49.7, 50.2, 49.5,
# 50.1, 50.3, 50.4, 50.5, 50.0, 50.7, 49.3, 49.8, 50.2, 50.9,
# 50.3, 50.4, 50.0, 49.7, 50.5, 49.9]

# %%
import numpy as np
from scipy.stats import norm

# Sample data
sample_data = [
    49.1, 50.2, 51.0, 48.7, 50.5, 49.8, 50.3, 50.7, 50.2, 49.6,
    50.1, 49.9, 50.8, 50.4, 48.9, 50.6, 50.0, 49.7, 50.2, 49.5,
    50.1, 50.3, 50.4, 50.5, 50.0, 50.7, 49.3, 49.8, 50.2, 50.9,
    50.3, 50.4, 50.0, 49.7, 50.5, 49.9
]

# Hypothesized population mean
mu_0 = 50

# Population standard deviation (assumed known)
sigma = 0.5

# Sample statistics
sample_mean = np.mean(sample_data)
n = len(sample_data)

# Z-statistic calculation
z = (sample_mean - mu_0) / (sigma / np.sqrt(n))

# Two-tailed p-value
p_value = 2 * (1 - norm.cdf(abs(z)))

# Significance level
alpha = 0.05

# Output results
print(f"Sample Mean = {sample_mean:.4f}")
print(f"Z-statistic = {z:.4f}")
print(f"P-value = {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: Significant difference from population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference from population mean.")
# Out:
# Sample Mean = 50.0889
# Z-statistic = 1.0667
# P-value = 0.2861
# Fail to reject the null hypothesis: No significant difference from population mean.

# %% [markdown]
# **Question 8: Write a Python script to simulate data from a normal distribution and
# calculate the 95% confidence interval for its mean. Plot the data using Matplotlib.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Simulate data from a normal distribution
np.random.seed(42)  # For reproducibility
mean = 100
std_dev = 15
sample_size = 100

data = np.random.normal(loc=mean, scale=std_dev, size=sample_size)

# Calculate the 95% confidence interval for the mean
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)  # Use sample standard deviation
confidence_level = 0.95
alpha = 1 - confidence_level

# Get the t-critical value (since sigma is unknown)
t_critical = stats.t.ppf(1 - alpha/2, df=sample_size - 1)

# Margin of error
margin_of_error = t_critical * (sample_std / np.sqrt(sample_size))

# Confidence interval
ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

# Step 3: Plot the histogram with confidence interval
plt.hist(data, bins=15, edgecolor='black', alpha=0.7)
plt.axvline(sample_mean, color='red', linestyle='--', label=f'Mean = {sample_mean:.2f}')
plt.axvline(ci_lower, color='green', linestyle='--', label=f'95% CI Lower = {ci_lower:.2f}')
plt.axvline(ci_upper, color='green', linestyle='--', label=f'95% CI Upper = {ci_upper:.2f}')
plt.title('Histogram of Simulated Normal Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# Print results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Sample Mean: 98.44
# 95% Confidence Interval: (95.74, 101.15)

# %% [markdown]
# **Question 9: Write a Python function to calculate the Z-scores from a dataset and
# visualize the standardized data using a histogram. Explain what the Z-scores represent
# in terms of standard deviations from the mean.**

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_z_scores(data):
    # Calculate mean and standard deviation
    mean = np.mean(data)
    std_dev = np.std(data)

    # Calculate Z-scores
    z_scores = [(x - mean) / std_dev for x in data]

    # Plot histogram of Z-scores
    plt.hist(z_scores, bins=15, edgecolor='black', alpha=0.7)
    plt.title('Histogram of Z-scores (Standardized Data)')
    plt.xlabel('Z-score')
    plt.ylabel('Frequency')
    plt.axvline(0, color='red', linestyle='--', label='Mean (Z = 0)')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Print a few sample Z-scores
    print("Sample Z-scores (first 5):", z_scores[:5])
    return z_scores

# Example usage with a sample dataset
sample_data = [55, 60, 65, 70, 75, 80, 85, 90, 95, 100]
z_scores = calculate_and_plot_z_scores(sample_data)
# Out:
# Sample Z-scores (first 5): [np.float64(-1.5666989036012806), np.float64(-1.2185435916898848), np.float64(-0.8703882797784892), np.float64(-0.5222329678670935), np.float64(-0.17407765595569785)]
